# %% [markdown]
# <a href="https://colab.research.google.com/github/VitorBZS/am-t4-s1a2026/blob/main/NeuralizadorCredit0423.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pipeline | Carregamento e Detecção Anomalias [Fase 1 - credit_data]

# %% [markdown]
# ## Importa dados do Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Blibliotecas de Python

# %%
# !pip -q install plotly
# !pip -q install yellowbrick

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ## Carregar Digest de base_credit

# %%
import pickle

# %%
with open('/content/drive/MyDrive/amt4/credit.pkt', 'rb') as f:
  X_credit_treinamento, Y_credit_terinamento, X_credit_teste, Y_credit_teste = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_11198/4240679697.py in <cell line: 0>()
# ----> 1 with open('/content/drive/MyDrive/amt4/credit.pkt', 'rb') as f:
#       2   X_credit_treinamento, Y_credit_terinamento, X_credit_teste, Y_credit_teste = pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/amt4/credit.pkt'

# %%
X_credit_treinamento.shape, Y_credit_treinamento.shape

# %%
X_credit_teste.shape, Y_credit_teste.shape

# %%
from sklearn.native_bayes import GaussianNB

# %%
native_credit_data = GaussianNB()
native_credit_data.fit(X_credit_treinamento, Y_credit_terinamento)
