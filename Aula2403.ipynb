# %% [markdown]
# <a href="https://colab.research.google.com/github/VitorBZS/am-t4-s1a2026/blob/main/Aula2403.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução de Python

# %%
a=2
b=3
print('A soma é: ' ,a+b)
# Out:
# A soma é:  5

# %% [markdown]
# ## Segunda Camada

# %%
c=4
d=5
print('A multiplicação é:' ,c*d)
# Out:
# A multiplicação é: 20

# %% [markdown]
# #Blibiotecas e Funções de Python

# %%
import math

def equacao2grau(a, b, c):
  delta = b**2 - 4*a*c

  if(delta < 0):
    return 'Numero sem Raiz', delta

  x1 = (-b + math.sqrt(delta)) / (2*a)
  x2 = (-b - math.sqrt(delta)) / (2*a)

  return x1, x2

# %% [markdown]
# ##Teste Função Matemática

# %%
eq = equacao2grau(1, -3, 2)
print(eq)
# Out:
# (2.0, 1.0)

# %%
import random
for i in range(5):
  a = random.randint(-5, 5)
  b = random.randint(-10, 10)
  c = random.randint(-10, 10)

  eq += equacao2grau(a, b, c)

# %%
print(eq)
# Out:
# (2.0, 1.0, -0.5866068747318506, 2.386606874731851, 5.0, -1.0, 1.7320508075688772, -1.7320508075688772, 'Numero sem Raiz', -36, 4.7912878474779195, 0.20871215252208009)
